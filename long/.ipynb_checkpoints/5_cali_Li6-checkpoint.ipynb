// %%
//%jsroot on

#include "TCutG.h"

// %%
#define _15C 28
#define NUM 100
#define _N 6

// %%
/******************/
Int_t stripnum=1;
/******************/

// %%
int start = 16;
int stop = 24;
TChain *fch;
fch = new TChain("tree", "tree");
for (int i= start; i<=stop; i++){
  TString fileName = TString::Format("/home/long/data/25e04/10Be/hit/run%02d_hit.root" , i);
  fch->AddFile(fileName.Data());
}
// fch->Print();

// %%
TCanvas *c1=new TCanvas("c1","c1");

Double_t silicon_thickness = 284.; // Microns
string ss;
Double_t aa, bbb, e, dedx;
// i=0;
Double_t E0=0.,Etem=0.,Esmall=0.,E2=0.,E=0.,dE=0.,x=0.,dx=0.25;
Double_t sep[_N][NUM];

// %%
TString  lise_cal;
lise_cal = TString::Format("/home/long/scripts/exp_scripts/lise/6Li_Si.txt");

TGraph *g_1;

std::ifstream in_1(lise_cal.Data());

g_1 = new TGraph;

if(in_1.is_open())
{
    Int_t i = 0; 
    while(!in_1.eof())
    {
        in_1>>aa>>bbb>>e>>dedx>>aa>>bbb>>aa>>bbb>>aa>>bbb>>aa>>bbb>>aa>>bbb;
        
        g_1->SetPoint(i++, e*6,dedx);//6Li.    
    }
}
in_1.close();

c1->cd();
g_1->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1757951278046" style="width: 700px; height: 500px; position: relative">
// </div>
//
// <script>
//
// function display_root_plot_1757951278046(Core) {
//    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-41250.0029983647,"fY1":-0.0697928441906634,"fX2":371250.002398365,"fY2":0.660440604190663,"fXtoAbsPixelk":69.6000041484835,"fXtoPixelk":69.6000041484835,"fXtoPixel":0.00168727270519817,"fYtoAbsPixelk":426.888094305986,"fYtoPixelk":426.888094305986,"fYtoPixel":-646.368638750059,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-41250.0029983647,"fPixeltoXk":-41250.0029983647,"fPixeltoX":592.672421547025,"fAbsPixeltoYk":0.660440604190663,"fPixeltoYk":-0.0697928441906634,"fPixeltoY":-0.00154710476351976,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0.003230505,"fUxmax":329999.9994,"fUymax":0.587417255,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33 ...

// %%
Double_t d[_N-1];
Int_t k; //kind  0:Si 1:Al 2:Mylar
            
d[0]=0.;
d[1]=0.;
d[2]=0.;
d[3]=silicon_thickness;
d[4]=100000.;

for(int i=1;i<(_N-1);i++)
    {
        d[i]=d[i]+d[i-1];
        // std::cout << "d[" << i << "]=" << d[i] << "\n";
    }
for(int i=0;i<NUM;i++)   // Start simulation based on NUM events
{
    if(i%30==0)std::cout<<i<<":"<<NUM<<'\n';
    x=0;

    // First half of events NUM, energy from 0 to 40 MeV
    if(i<=NUM)E0=E=i*200./(Double_t)(NUM);

    for(Int_t j=0;j<_N;j++)sep[j][i]=0;
    sep[_N-1][i]=E0;
    Etem=E0;
    k=0;
    //cout<<" Y1"<<'\n';
    x=0.;
    while(1)
    {
        if((fabs(x-d[0])<=(dx/40.)||(x>=0&&x<d[0]))&&E<=0){sep[0][i]=Etem;Etem=0;break;}
        else if(fabs(x-d[0])<=(dx/40.)&&E>0){if(k!=0){sep[0][i]=E0-E;Etem=E;}k=0;}

        else if((fabs(x-d[1])<=(dx/2.)||(x>d[0]&&x<d[1]))&&E<=0){sep[1][i]=Etem;Etem=0;break;}
        else if(fabs(x-d[1])<=(dx/2.)&&E>0){if(k!=1){sep[1][i]=Etem-E;Etem=E;}k=1;}

        else if((fabs(x-d[2])<=(dx/2.)||(x>d[1]&&x<d[2]))&&E<=0){sep[2][i]=Etem;Etem=0;break;}
        else if(fabs(x-d[2])<=(dx/2.)&&E>0){if(k!=3){sep[2][i]=Etem-E;Etem=E;}k=3;}
        
        else if((fabs(x-d[3])<=(dx/2.)||(x>d[2]&&x<d[3]))&&E<=0){sep[3][i]=Etem;Etem=0;break;}
        else if(fabs(x-d[3])<=(dx/2.)&&E>0){if(k!=2){sep[3][i]=Etem-E;Etem=E;}k=2;}

        else if(((fabs(x-d[4])>(dx/40.)&&x>d[4])&&E<=0)){sep[4][i]=Etem;Etem=0;break;}
        else if(((fabs(x-d[4])>(dx/40.)&&x>d[4])&&E>0)){sep[4][i]=Etem-E;Etem=0;break;}
        else if(fabs(x-d[4])<=(dx/40.)&&E>0){if(k!=0){sep[4][i]=Etem-E;Etem=E;}k=0;}
        
        dE=g_1->Eval(E);
        E=E-dE*dx;
        x=x+dx;
    }
}
// Out:
// 0:100
// 30:100
// 60:100
// 90:100

// %%
TGraph *cal_pid;
cal_pid = new TGraph();

Int_t keypid=1;
Int_t ip=0,i03=0,i23=0,i43=0;

for(Int_t i0=0;i0<NUM;)
{
    if(keypid==1&&sep[4][i0]>0)cal_pid->SetPoint(ip++, sep[3][i0],sep[4][i0]);       
    i0++;
}
ip=0;
i03=0;
i23=0;
i43=0;
keypid=0;

c1->Clear();
cal_pid->SetMarkerStyle(3);
cal_pid->Draw("ap");
c1->Draw();
// Out:
// <div id="root_plot_1757951289942" style="width: 700px; height: 500px; position: relative">
// </div>
//
// <script>
//
// function display_root_plot_1757951289942(Core) {
//    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.652316124133907,"fY1":-19.3688033162967,"fX2":47.2265971992742,"fY2":233.141263697172,"fXtoAbsPixelk":-9.74812733372573,"fXtoPixelk":-9.74812733372573,"fXtoPixel":14.9438699628474,"fYtoAbsPixelk":435.795205183624,"fYtoPixelk":435.795205183624,"fYtoPixel":-1.86923240559286,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0.652316124133907,"fPixeltoXk":0.652316124133907,"fPixeltoX":0.066917070510259,"fAbsPixeltoYk":233.141263697172,"fPixeltoYk":-19.3688033162967,"fPixeltoY":-0.53497895553701,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":5.30974450925229,"fUymin":5.88220489012755,"fUxmax":42.5691688141558,"fUymax":207.890255490748,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:1 ...

// %%
gROOT->Macro("/home/long/data/25e04/10Be/hit/test_cut.C");
TCutG *test_cut = (TCutG *)gROOT->GetListOfSpecials()->FindObject("test_cut");
// Out:
// <div id="root_plot_1757951290161" style="width: 700px; height: 500px; position: relative">
// </div>
//
// <script>
//
// function display_root_plot_1757951290161(Core) {
//    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.652316124133907,"fY1":-19.3688033162967,"fX2":47.2265971992742,"fY2":233.141263697172,"fXtoAbsPixelk":-9.74812733372573,"fXtoPixelk":-9.74812733372573,"fXtoPixel":14.9438699628474,"fYtoAbsPixelk":435.795205183624,"fYtoPixelk":435.795205183624,"fYtoPixel":-1.86923240559286,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0.652316124133907,"fPixeltoXk":0.652316124133907,"fPixeltoX":0.066917070510259,"fAbsPixeltoYk":233.141263697172,"fPixeltoYk":-19.3688033162967,"fPixeltoY":-0.53497895553701,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":5.30974450925229,"fUymin":5.88220489012755,"fUxmax":42.5691688141558,"fUymax":207.890255490748,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:1 ...

// %%
c1->Clear();

double a = 20.;
double b = -0.0107;

double min_fit = 180.;
double max_fit = 220.;
double avg = (min_fit+max_fit)/2.;
double avg_diff = avg-min_fit;

// TString name = TString::Format("(TMath::Sqrt(Rxc[0]*Rea[0]+%f*Rxc[0]*Rxc[0])+%f*Rea[0]):Rea[0]>>(1000,0,8000,1000,0.,400.)",a,b);
// TString name = TString::Format("(TMath::Sqrt(Rxc[0]*Rea[0]+%f*Rxc[0]*Rxc[0])+%f*Rea[0])>>(500,%f,%f)",a,b,min_fit,max_fit);
TString name = "Rxc[0]:Rea[0]:Rxc[0]>>(1000,0,8000,1000,0.,70.)";
// TString name = "Rxc[0]:Rea[0]>>(1000,0,8000,1000,0.,70.)";

min_fit = 183.;
max_fit = 193.;
avg = (min_fit+max_fit)/2.;
avg_diff = avg-min_fit;

TString draw_condition = "Rxa_n[0]>=0 && Rxa_n[0]<=3 && Rya_n[0]>=12 && Rya_n[0]<=15";

draw_condition = draw_condition + Form("&& TMath::Abs(TMath::Sqrt(Rxc[0]*Rea[0]+(%f)*Rxc[0]*Rxc[0])+(%.5f)*Rea[0] - %f) < %f", a, b, avg, avg_diff);
draw_condition = draw_condition + "&& af3>1500. && af3<3000. && ToF>170. && ToF<220.";
draw_condition = draw_condition + "&& xbt*xbt+ybt*ybt<100.";
draw_condition = draw_condition + "&& Rea_n[0]==0";
draw_condition = draw_condition + "&& test_cut";
// std::cout << "c_number: " << c_number << "\n";

// fch->Draw(name.Data(),draw_condition.Data(),"colz");
Int_t num1=fch->Draw(name.Data(),draw_condition.Data());
c1->Draw();
if(num1==0) return;

TGraph2D *e1=new TGraph2D(num1,fch->GetV3(),fch->GetV2(),fch->GetV1());
Int_t npoints1=e1->GetN();
// Out:
// <div id="root_plot_1757951295937" style="width: 700px; height: 500px; position: relative">
// </div>
//
// <script>
//
// function display_root_plot_1757951295937(Core) {
//    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1,"fY1":-1,"fX2":1,"fY2":1,"fXtoAbsPixelk":348,"fXtoPixelk":348,"fXtoPixel":348,"fYtoAbsPixelk":236,"fYtoPixelk":236,"fYtoPixel":-236,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-1,"fPixeltoXk":-1,"fPixeltoX":0.0028735632183908,"fAbsPixeltoYk":1,"fPixeltoYk":-1,"fPixeltoY":-0.00423728813559322,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1,"fUymin":-1,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113:173,173,125;114:134,200,221;115:87,141,255;116:101,99,100;117:63,144,218;118:255,169,14;119:189,31,1;120:148,164,162;121:131,45,182;122:169,107,89;123:231,99,0;124:185, ...

// %%
TGraph *evalcheck = new TGraph();

TGraph *result;
result = new TGraph();

TGraph *indeedpid;
indeedpid = new TGraph();

Double_t kk,bb;

Double_t *gex=e1->GetY(); // Energy deposit
Double_t *gey=e1->GetZ(); // delta E

// %%
Int_t J=0;

// %%
// First make linear fit
TGraph *tempresult;
tempresult = new TGraph();

J=0;
for(Int_t i=0;i<npoints1;i++){
   if(gey[i]>0.3&&gex[i]>=100&&gex[i]<9000)
   {
       double new_point = cal_pid->Eval(gey[i]);
       tempresult->SetPoint(J,new_point,gex[i]);
       J++;
   }
}

tempresult->Draw("ap");
c1->Draw();
TF1 *f3 = new TF1("f3","[1]*x+[0]",1,100);
f3->SetParameter(0,200);
f3->SetParameter(1,0);
TFitResultPtr r1 = tempresult->Fit("f3","S+rob=0.9","",1.,130.);
kk=r1->Value(1);
bb=r1->Value(0);
cout<<"N="<<npoints1<<'\n';
cout<<"i="<<J<<" kp="<<kk<<" bp="<<bb<<'\n';
// Out:
// <div id="root_plot_1757951830504" style="width: 700px; height: 500px; position: relative">
// </div>
//
// <script>
//
// function display_root_plot_1757951830504(Core) {
//    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-16.9270402843663,"fY1":-278.225042052942,"fX2":152.343352469995,"fY2":5366.02504205294,"fXtoAbsPixelk":69.6000041484835,"fXtoPixelk":69.6000041484835,"fXtoPixel":4.11176454827519,"fYtoAbsPixelk":448.73345123052,"fYtoPixelk":448.73345123052,"fYtoPixel":-0.0836249267779867,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":696,"fVtoAbsPixelk":472,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-16.9270402843663,"fPixeltoXk":-16.9270402843663,"fPixeltoX":0.243204587290749,"fAbsPixeltoYk":5366.02504205294,"fPixeltoYk":-278.225042052942,"fPixeltoY":-11.9581569578515,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":286.2,"fUxmax":135.416312185629,"fUymax":4801.6,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"c1","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":14.28571,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":696,"fCh":472,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251 ...
// ****************************************
// Minimizer is Minuit2 / Migrad
// Chi2                      =  8.15243e+06
// NDf                       =         1686
// Edm                       =  7.27585e-15
// NCalls                    =           35
// p0                        =     -179.211   +/-   4.99044
// p1                        =      36.0368   +/-   0.0724832
// N=1688
// i=1688 kp=36.0368 bp=-179.211

// %%
Int_t ni[3];
for(ni[0]=2;ni[0]<10;ni[0]++)
{
    J=0;
    for(Int_t i=0;i<npoints1;i++)
    {
        if((abs((gex[i]-cal_pid->Eval(gey[i])*kk[0][ni[0]-1]+bb[0][ni[0]-1])))<500))
        {
           if(gey[i]>0.3&&gex[i]>=500&&gex[i]<30000)
           {
               double new_point = cal_pid->Eval(gey[i]);
               tempresult[0][ni[0]]->SetPoint(J,new_point,gex[i]);J++;
           }  
        }
    }
    TFitResultPtr r4 =tempresult[0][ni[0]]->Fit("f3","S+rob=0.9","",15.,130.);
    kk[0][ni[0]]=r4->Value(1);
    bb[0][ni[0]]=r4->Value(0);
    cout<<ni[0]<<" J= "<<J<<" kp="<<kk[0][ni[0]]<<" bp="<<bb[0][ni[0]]<<'\n';
    if(kk[0][ni[0]]==kk[0][ni[0]-1])break;
}
if(ni[0]==10)ni[0]=9;
tempresult[0][ni[0]]->Draw("ap");
c1->Draw();
// Out:
// input_line_115:8:49: error: subscripted value is not an array, pointer, or vector
//         if((abs((gex[i]-cal_pid->Eval(gey[i])*kk[0][ni[0]-1]+bb[0][ni[0]-1])))<500))
//                                               ~~^~
// input_line_115:8:64: error: subscripted value is not an array, pointer, or vector
//         if((abs((gex[i]-cal_pid->Eval(gey[i])*kk[0][ni[0]-1]+bb[0][ni[0]-1])))<500))
//                                                              ~~^~
// input_line_115:8:84: error: extraneous ')' after condition, expected a statement
//         if((abs((gex[i]-cal_pid->Eval(gey[i])*kk[0][ni[0]-1]+bb[0][ni[0]-1])))<500))
//                                                                                    ^
// input_line_115:13:29: error: type 'TGraph' does not provide a subscript operator
//                tempresult[0][ni[0]]->SetPoint(J,new_point,gex[i]);J++;
//                ~~~~~~~~~~~~~^~~~~~
// input_line_115:17:36: error: type 'TGraph' does not provide a subscript operator
//     TFitResultPtr r4 =tempresult[0][ni[0]]->Fit("f3","S+rob=0.9","",15.,130.);
//                       ~~~~~~~~~~~~~^~~~~~
// input_line_115:18:7: error: subscripted value is not an array, pointer, or vector
//     kk[0][ni[0]]=r4->Value(1);
//     ~~^~
// input_line_115:19:7: error: subscripted value is not an array, pointer, or vector
//     bb[0][ni[0]]=r4->Value(0);
//     ~~^~
// input_line_115:20:39: error: subscripted value is not an array, pointer, or vector
//     cout<<ni[0]<<" J= "<<J<<" kp="<<kk[0][ni[0]]<<" bp="<<bb[0][ni[0]]<<'\n';
//                                     ~~^~
// input_line_115:20:61: error: subscripted value is not an array, pointer, or vector
//     cout<<ni[0]<<" J= "<<J<<" kp="<<kk[0][ni[0]]<<" bp="<<bb[0][ni[0]]<<'\n';
//                                                           ~~^~
// input_line_115:21:10: error: subscripted value is not an array, pointer, or vector
//     if(kk[0][ni[0]]==kk[0][ni[0]-1])break;
//        ~~^~
// input_line_115:21:24: error: subscripted value is not an array, pointer, or vector
//     if(kk[0][ni[0]]==kk[0][ni[0]-1])break;
//                      ~~^~
// input_line_115:24:14: error: type 'TGraph' does not provide a subscript operator
// tempresult[0][ni[0]]->Draw("ap");
// ~~~~~~~~~~~~~^~~~~~

// %%
Double_t a0[3],a1[3],a2[3];

// %%
J=0;
for(Int_t i=0;i<npoints1;i++){
   if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200))
   {
       if(gey[i]>0.3&&gex[i]>=500&&(gex[i]<=3000||(gex[i]>3000&&gex[i]<=6000&&i%10<=2)||(gex[i]>6000&&gex[i]<35000&&i%10<=1)))
       {
               tempresult[0][0]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]);
               J++;              
       }
   }
}
TF1 *f1 = new TF1("f1","[0]*x-[0]*[1]*TMath::Log(1+x/[1])+[2]",1,150);
f1->SetParameter(0,kk[0][ni[0]]);
f1->SetParLimits(1,0.01,10);
f1->SetParameter(2,bb[0][ni[0]]);
tempresult[0][0]->Fit("f1","R+rob0.9");

TF1 *fitp = tempresult[0][0]->GetFunction("f1");
a0[0] = fitp->GetParameter(0);
a1[0] = fitp->GetParameter(1);
a2[0] = fitp->GetParameter(2);
cout<<"a0= "<<a0[0]<<" a1= "<<a1[0]<<" a2="<<a2[0];
c1->Draw();
// Out:
// input_line_117:4:45: error: subscripted value is not an array, pointer, or vector
//    if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200))
//                                           ~~^~
// input_line_117:4:49: error: use of undeclared identifier 'ni'
//    if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200))
//                                                 ^
// input_line_117:4:58: error: subscripted value is not an array, pointer, or vector
//    if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200))
//                                                        ~~^~
// input_line_117:4:62: error: use of undeclared identifier 'ni'
//    if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200))
//                                                              ^
// input_line_117:8:29: error: type 'TGraph' does not provide a subscript operator
//                tempresult[0][0]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]);
//                ~~~~~~~~~~~~~^~
// input_line_117:14:22: error: subscripted value is not an array, pointer, or vector
// f1->SetParameter(0,kk[0][ni[0]]);
//                    ~~^~
// input_line_117:14:26: error: use of undeclared identifier 'ni'
// f1->SetParameter(0,kk[0][ni[0]]);
//                          ^
// input_line_117:16:22: error: subscripted value is not an array, pointer, or vector
// f1->SetParameter(2,bb[0][ni[0]]);
//                    ~~^~
// input_line_117:16:26: error: use of undeclared identifier 'ni'
// f1->SetParameter(2,bb[0][ni[0]]);
//                          ^
// input_line_117:17:14: error: type 'TGraph' does not provide a subscript operator
// tempresult[0][0]->Fit("f1","R+rob0.9");
// ~~~~~~~~~~~~~^~
// input_line_117:19:26: error: type 'TGraph' does not provide a subscript operator
// TF1 *fitp = tempresult[0][0]->GetFunction("f1");
//             ~~~~~~~~~~~~~^~

// %%
   J=0;
   for(Int_t i=0;i<npoints1;i++){
       if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
         //if((TMath::Abs((pid->Eval(gey[i])-(gex[i]*k[ni-1]+b[ni-1])))<10)){
       if(gey[i]>0.3&&gex[i]>=500&&gex[i]<30000){result[0]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]);J++;}
       }
   }
   J=0;
   // for(Double_t E=15.;E<150;E=E+0.01){
   //     indeedpid[0]->SetPoint(J++,E,a0[0]*E-a0[0]*a1[0]*TMath::Log(1+E/a1[0])+a2[0]);
   // }
    result[0]->Draw("ap");
    // indeedpid[0]->SetMarkerColor(2);
    // indeedpid[0]->Draw("samep");
    c1->Draw();

TF1 *ftest = new TF1("ftest","[0]*x-[0]*[1]*TMath::Log(1+x/[1])+[2]",15,130);
// ftest->SetParameter(0,a0[0]);
// ftest->SetParameter(0,a1[0]);
// ftest->SetParameter(2,a2[0]);
// tempresult[0][0]->Fit("ftest","R+rob0.9");
std::cout << "chi2 = " << result[0]->Chisquare(ftest) << "\n";
c1->Draw();
// Out:
// input_line_118:4:49: error: subscripted value is not an array, pointer, or vector
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                               ~~^~
// input_line_118:4:53: error: use of undeclared identifier 'ni'
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                     ^
// input_line_118:4:62: error: subscripted value is not an array, pointer, or vector
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                            ~~^~
// input_line_118:4:66: error: use of undeclared identifier 'ni'
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                                  ^
// input_line_118:6:59: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//        if(gey[i]>0.3&&gex[i]>=500&&gex[i]<30000){result[0]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]);J++;}
//                                                  ~~~~~~~~~^~
//                                                           .
// input_line_118:13:14: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     result[0]->Draw("ap");
//     ~~~~~~~~~^~
//              .
// input_line_118:23:36: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
// std::cout << "chi2 = " << result[0]->Chisquare(ftest) << "\n";
//                           ~~~~~~~~~^~
//                                    .

// %%
   J=0;
   for(Int_t i=0;i<npoints1;i++){
       if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
         //if((TMath::Abs((pid->Eval(gey[i])-(gex[i]*k[ni-1]+b[ni-1])))<10)){
       if(gey[i]>0.3&&gex[i]>=500&&gex[i]<4000){result[1]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]);J++;}
       }
   }
   J=0;
   for(Double_t E=15.;E<30;E=E+0.01){
       indeedpid[1]->SetPoint(J++,E,a0[0]*E-a0[0]*a1[0]*TMath::Log(1+E/a1[0])+a2[0]);
   }
    result[1]->Draw("ap");
    indeedpid[1]->SetMarkerColor(2);
    indeedpid[1]->Draw("samep");
    c1->Draw();
// Out:
// input_line_119:4:49: error: subscripted value is not an array, pointer, or vector
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                               ~~^~
// input_line_119:4:53: error: use of undeclared identifier 'ni'
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                     ^
// input_line_119:4:62: error: subscripted value is not an array, pointer, or vector
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                            ~~^~
// input_line_119:4:66: error: use of undeclared identifier 'ni'
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                                  ^
// input_line_119:6:58: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//        if(gey[i]>0.3&&gex[i]>=500&&gex[i]<4000){result[1]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]);J++;}
//                                                 ~~~~~~~~~^~
//                                                          .
// input_line_119:11:20: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//        indeedpid[1]->SetPoint(J++,E,a0[0]*E-a0[0]*a1[0]*TMath::Log(1+E/a1[0])+a2[0]);
//        ~~~~~~~~~~~~^~
//                    .
// input_line_119:13:14: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     result[1]->Draw("ap");
//     ~~~~~~~~~^~
//              .
// input_line_119:14:17: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     indeedpid[1]->SetMarkerColor(2);
//     ~~~~~~~~~~~~^~
//                 .
// input_line_119:15:17: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     indeedpid[1]->Draw("samep");
//     ~~~~~~~~~~~~^~
//                 .

// %%
   J=0;
   for(Int_t i=0;i<npoints1;i++){
       if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
         //if((TMath::Abs((pid->Eval(gey[i])-(gex[i]*k[ni-1]+b[ni-1])))<10)){
       if(gey[i]>0.3&&gex[i]>=500&&gex[i]<10000){result[2]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]-a0[0]*cal_pid->Eval(gey[i])-a2[0]);J++;}
       }
   }
   J=0;
   for(Double_t E=1.;E<60;E=E+0.01){
       indeedpid[2]->SetPoint(J++,E,-a0[0]*a1[0]*TMath::Log(1+E/a1[0]));
   }
    result[2]->Draw("ap");
    indeedpid[2]->SetMarkerColor(2);
    indeedpid[2]->Draw("samep");
    c1->Draw();
// Out:
// input_line_120:4:49: error: subscripted value is not an array, pointer, or vector
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                               ~~^~
// input_line_120:4:53: error: use of undeclared identifier 'ni'
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                     ^
// input_line_120:4:62: error: subscripted value is not an array, pointer, or vector
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                            ~~^~
// input_line_120:4:66: error: use of undeclared identifier 'ni'
//        if((abs((gex[i]-(cal_pid->Eval(gey[i])*kk[0][ni[0]]+bb[0][ni[0]])))<1200)){
//                                                                  ^
// input_line_120:6:59: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//        if(gey[i]>0.3&&gex[i]>=500&&gex[i]<10000){result[2]->SetPoint(J,cal_pid->Eval(gey[i]),gex[i]-a0[0]*cal_pid->Eval(gey[i])-a2[0]);J++;}
//                                                  ~~~~~~~~~^~
//                                                           .
// input_line_120:11:20: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//        indeedpid[2]->SetPoint(J++,E,-a0[0]*a1[0]*TMath::Log(1+E/a1[0]));
//        ~~~~~~~~~~~~^~
//                    .
// input_line_120:13:14: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     result[2]->Draw("ap");
//     ~~~~~~~~~^~
//              .
// input_line_120:14:17: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     indeedpid[2]->SetMarkerColor(2);
//     ~~~~~~~~~~~~^~
//                 .
// input_line_120:15:17: error: member reference type 'TGraph' is not a pointer; did you mean to use '.'?
//     indeedpid[2]->Draw("samep");
//     ~~~~~~~~~~~~^~
//                 .

// %%
for(Int_t ii=0;ii<1;ii++){
    cout<<a0[ii]<<'\t'<<a1[ii]<<'\t'<<a2[ii]<<'\n';
}
// Out:
// 0	0	0
