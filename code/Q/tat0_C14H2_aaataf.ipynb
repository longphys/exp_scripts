// %%
//%jsroot on

// %%
//Q = (ma/mB− 1 )Ea + (mb/mB+ 1 )Eb −2cos(theta)*sqrt(ma*mb*Ea*Eb)/mB
//15C+p->d+14C      a=15C A=p b=d  B=14C
//ma=15.0105993 mb=2.01410177811 mB=14.003241988 Ea=27 MeV Eb_Etheta
//Q0=+1.01

// %%
#define _bin  40
#define _15C 28.3
#define _H2offset +0.0
#define _thetaoffset -0.

// %%
Double_t mean[12],sigma[12],meanangle[12];
Double_t mean2[12],sigma2[12],meanangle2[12];
Double_t eoff[12]={0.9,0.9,0.9,0.9,   0.5,0.5,0.5,0.5,  0.5,0.5,0.5,0.5};
Double_t eoffx2[12]={0.002,0.,0.0020,0.002,   0.001,0.0005,0.003,0.0025,   0.0022,0.0015,0.003,0.0025};
//double eoff[12]={-1.5,-1.5,-1,-1, -1,-1,0,0, -1,-1,-1.5,-1.5};
Double_t theoff[12]={0.34,0.93,-0.5,-0.1,        -0.4,-0.7,0.5,-0.35,           1.2,1.44,0.8,0.95};
//ave************: ad0 0.635 ad1 -0.3 ad2 -0.55 ad3 0.075 ad4 1.32 ad5 0.875****************
//Double_t theoff[12]={-0.46+0.8,0.13+0.8,-1.00+0.8,-0.9+0.8,        -1.2+0.8,-1.5+0.8,-0.3+0.8,-1.15+0.8,           0.4+0.8,0.64+0.8,0.0+0.8,0.15+0.8};
//double theoff[12]={0,0.5,0,0, -0.5,-0.5,0,-0.5, 1.,0,0.5,1.5};
TF1 *g1 = new TF1("g1","gaus");

// %%
Double_t anglemax_0=0,anglemax_6600=0;

Double_t Q,Ex,Theta;
Int_t i;
TGraph *T1Etheta_B14He3_0= new TGraph;
Double_t Ex_0=0;
  for(Theta=0;Theta<50;Theta=Theta+0.2){
    for(Ex=0;Ex<200;Ex=Ex+0.001){
    Q=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*Ex
       -2.*cos(Theta*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*Ex)/14.003241988);
        if(abs(Q-Ex_0)<0.01){
            T1Etheta_B14He3_0->SetPoint(i++,Theta,Ex);
            if(Theta>anglemax_0)anglemax_0=Theta;
        }
    }
  }


TGraph *T1Etheta_B14He3_6100= new TGraph;
Double_t Ex_6100=6.094;
  for(Theta=0;Theta<50;Theta=Theta+0.2){
    for(Ex=0;Ex<200;Ex=Ex+0.001){
    Q=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*Ex
       -2.*cos(Theta*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*Ex)/14.003241988);
        if(abs(Q-Ex_6100)<0.01){
            T1Etheta_B14He3_6100->SetPoint(i++,Theta,Ex);
            if(Theta>anglemax_6600)anglemax_6600=Theta;
        }
    }
  }
cout<<"anglemax_0="<<anglemax_0<<'\t'<<"anglemax_6600="<<anglemax_6600<<'\n';
TGraph *T1Etheta_B14He3_10000= new TGraph;
Double_t Ex_10000=11.4;
  for(Theta=0;Theta<50;Theta=Theta+0.2){
    for(Ex=0;Ex<200;Ex=Ex+0.001){
    Q=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*Ex
       -2.*cos(Theta*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*Ex)/14.003241988);
    //if(abs(Q-Ex_10000)<0.01)T1Etheta_B14He3_6100->SetPoint(i++,Theta,Ex);
    }
  }
/*
TGraph *T1Etheta_B14He3_1860= new TGraph;
Double_t Ex_1860=1.86;
  for(Theta=0;Theta<50;Theta=Theta+0.2){
    for(Ex=0;Ex<200;Ex=Ex+0.001){
    Q=-15.59-((15.0106/14.0254-1.)*(_15C*15)+(3.01603/14.0254+1.)*Ex
       -2.*cos(Theta*3.14159/180.)*sqrt(15.0106*3.01603*_15C*15*Ex)/14.025404);
    if(abs(Q-Ex_1860)<0.01)T1Etheta_B14He3_1860->SetPoint(i++,Theta,Ex);
    }
  }

TGraph *T1Etheta_B14He3_4500= new TGraph;
Double_t Ex_4500=4.5;
  for(Theta=0;Theta<50;Theta=Theta+0.2){
    for(Ex=0;Ex<200;Ex=Ex+0.001){
    Q=-15.59-((15.0106/14.0254-1.)*(_15C*15)+(3.01603/14.0254+1.)*Ex
       -2.*cos(Theta*3.14159/180.)*sqrt(15.0106*3.01603*_15C*15*Ex)/14.025404);
    if(abs(Q-Ex_4500)<0.01)T1Etheta_B14He3_4500->SetPoint(i++,Theta,Ex);
    }
  }
  */

Int_t ii0=0;
// Out:
// anglemax_0=44	anglemax_6600=37.8

// %%
TCanvas *c1=new TCanvas;

// %%
TGraph *T1E_newtheta_new_bydstar_0A= new TGraph;
TGraph *T1E_newtheta_new_bydstar_0B= new TGraph;
TGraph *T1E_newtheta_new_bydstar_1A= new TGraph;
TGraph *T1E_newtheta_new_bydstar_1B= new TGraph;
TGraph *T1E_newtheta_new_bydstar_2A= new TGraph;
TGraph *T1E_newtheta_new_bydstar_2B= new TGraph;
TGraph *T1E_newtheta_new_bydstar_3A= new TGraph;
TGraph *T1E_newtheta_new_bydstar_3B= new TGraph;
TGraph *T1E_newtheta_new_bydstar_4A= new TGraph;
TGraph *T1E_newtheta_new_bydstar_4B= new TGraph;
TGraph *T1E_newtheta_new_bydstar_5A= new TGraph;
TGraph *T1E_newtheta_new_bydstar_5B= new TGraph;
TGraph *T1E_newtheta_new_bydstar_all= new TGraph;

// %%
TString fileName_0A = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad0_ac0A_theta_delay_tarloss.root");
TString fileName_0B = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad0_ac0B_theta_delay_tarloss.root");
TString fileName_1A = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad1_ac1A_theta_delay_tarloss.root");
TString fileName_1B = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad1_ac1B_theta_delay_tarloss.root");
TString fileName_2A = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad2_ac2A_theta_delay_tarloss.root");
TString fileName_2B = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad2_ac2B_theta_delay_tarloss.root");
TString fileName_3A = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad3_ac3A_theta_delay_tarloss.root");
TString fileName_3B = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad3_ac3B_theta_delay_tarloss.root");
TString fileName_4A = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad4_ac4A_theta_delay_tarloss.root");
TString fileName_4B = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad4_ac4A_theta_delay_tarloss.root");
TString fileName_5A = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad5_ac5A_theta_delay_tarloss.root");
TString fileName_5B = TString::Format("/home/zhuhy/JNBook/Experiment2022/taf/taf_E_theta/graph_2H/Ctar_all_14C0_all_2H_taf_ad5_ac5B_theta_delay_tarloss.root");
TFile *ipf_0A = new TFile(fileName_0A.Data(),"read");
TFile *ipf_0B = new TFile(fileName_0B.Data(),"read");
TFile *ipf_1A = new TFile(fileName_1A.Data(),"read");
TFile *ipf_1B = new TFile(fileName_1B.Data(),"read");
TFile *ipf_2A = new TFile(fileName_2A.Data(),"read");
TFile *ipf_2B = new TFile(fileName_2B.Data(),"read");
TFile *ipf_3A = new TFile(fileName_3A.Data(),"read");
TFile *ipf_3B = new TFile(fileName_3B.Data(),"read");
TFile *ipf_4A = new TFile(fileName_4A.Data(),"read");
TFile *ipf_4B = new TFile(fileName_4B.Data(),"read");
TFile *ipf_5A = new TFile(fileName_5A.Data(),"read");
TFile *ipf_5B = new TFile(fileName_5B.Data(),"read");
TCanvas *T1Etheta_new_0A=(TCanvas *)ipf_0A->Get("T1Etheta_new");
TCanvas *T1Etheta_new_0B=(TCanvas *)ipf_0B->Get("T1Etheta_new");
TCanvas *T1Etheta_new_1A=(TCanvas *)ipf_1A->Get("T1Etheta_new");
TCanvas *T1Etheta_new_1B=(TCanvas *)ipf_1B->Get("T1Etheta_new");
TCanvas *T1Etheta_new_2A=(TCanvas *)ipf_2A->Get("T1Etheta_new");
TCanvas *T1Etheta_new_2B=(TCanvas *)ipf_2B->Get("T1Etheta_new");
TCanvas *T1Etheta_new_3A=(TCanvas *)ipf_3A->Get("T1Etheta_new");
TCanvas *T1Etheta_new_3B=(TCanvas *)ipf_3B->Get("T1Etheta_new");
TCanvas *T1Etheta_new_4A=(TCanvas *)ipf_4A->Get("T1Etheta_new");
TCanvas *T1Etheta_new_4B=(TCanvas *)ipf_4B->Get("T1Etheta_new");
TCanvas *T1Etheta_new_5A=(TCanvas *)ipf_5A->Get("T1Etheta_new");
TCanvas *T1Etheta_new_5B=(TCanvas *)ipf_5B->Get("T1Etheta_new");
TGraph *T1Etheta_new_bydstar_0A=(TGraph *)ipf_0A->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_0B=(TGraph *)ipf_0B->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_1A=(TGraph *)ipf_1A->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_1B=(TGraph *)ipf_1B->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_2A=(TGraph *)ipf_2A->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_2B=(TGraph *)ipf_2B->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_3A=(TGraph *)ipf_3A->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_3B=(TGraph *)ipf_3B->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_4A=(TGraph *)ipf_4A->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_4B=(TGraph *)ipf_4B->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_5A=(TGraph *)ipf_5A->Get("T1Etheta_new_bydstar");
TGraph *T1Etheta_new_bydstar_5B=(TGraph *)ipf_5B->Get("T1Etheta_new_bydstar");




Int_t npoints_0A=T1Etheta_new_bydstar_0A->GetN();
Int_t npoints_0B=T1Etheta_new_bydstar_0B->GetN();
Int_t npoints_1A=T1Etheta_new_bydstar_1A->GetN();
Int_t npoints_1B=T1Etheta_new_bydstar_1B->GetN();
Int_t npoints_2A=T1Etheta_new_bydstar_2A->GetN();
Int_t npoints_2B=T1Etheta_new_bydstar_2B->GetN();
Int_t npoints_3A=T1Etheta_new_bydstar_3A->GetN();
Int_t npoints_3B=T1Etheta_new_bydstar_3B->GetN();
Int_t npoints_4A=T1Etheta_new_bydstar_4A->GetN();
Int_t npoints_4B=T1Etheta_new_bydstar_4B->GetN();
Int_t npoints_5A=T1Etheta_new_bydstar_5A->GetN();
Int_t npoints_5B=T1Etheta_new_bydstar_5B->GetN();
Double_t *Eb_0A=T1Etheta_new_bydstar_0A->GetY();
Double_t *Eb_0B=T1Etheta_new_bydstar_0B->GetY();
Double_t *Eb_1A=T1Etheta_new_bydstar_1A->GetY();
Double_t *Eb_1B=T1Etheta_new_bydstar_1B->GetY();
Double_t *Eb_2A=T1Etheta_new_bydstar_2A->GetY();
Double_t *Eb_2B=T1Etheta_new_bydstar_2B->GetY();
Double_t *Eb_3A=T1Etheta_new_bydstar_3A->GetY();
Double_t *Eb_3B=T1Etheta_new_bydstar_3B->GetY();
Double_t *Eb_4A=T1Etheta_new_bydstar_4A->GetY();
Double_t *Eb_4B=T1Etheta_new_bydstar_4B->GetY();
Double_t *Eb_5A=T1Etheta_new_bydstar_5A->GetY();
Double_t *Eb_5B=T1Etheta_new_bydstar_5B->GetY();
Double_t *theta_0A=T1Etheta_new_bydstar_0A->GetX();
Double_t *theta_0B=T1Etheta_new_bydstar_0B->GetX();
Double_t *theta_1A=T1Etheta_new_bydstar_1A->GetX();
Double_t *theta_1B=T1Etheta_new_bydstar_1B->GetX();
Double_t *theta_2A=T1Etheta_new_bydstar_2A->GetX();
Double_t *theta_2B=T1Etheta_new_bydstar_2B->GetX();
Double_t *theta_3A=T1Etheta_new_bydstar_3A->GetX();
Double_t *theta_3B=T1Etheta_new_bydstar_3B->GetX();
Double_t *theta_4A=T1Etheta_new_bydstar_4A->GetX();
Double_t *theta_4B=T1Etheta_new_bydstar_4B->GetX();
Double_t *theta_5A=T1Etheta_new_bydstar_5A->GetX();
Double_t *theta_5B=T1Etheta_new_bydstar_5B->GetX();

// %%
/*
c1->Clear();
T1Etheta_new_bydstar_a->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
c1->Draw();
*/
//Q = (ma/mB− 1 )Ea + (mb/mB+ 1 )Eb −2cos(theta)*sqrt(ma*mb*Ea*Eb)/mB
//15C(d,3He)14B Q=-15.19
//15C+d->3He+14B      a=15C A=d b=3He  B=14B
//ma=15.0105993 mb=3.01602932265 mB=14.025404 Ea=27 MeV Eb_Etheta

// %%
TH1D *q_all=new TH1D("Ex_all","Ex_all",_bin*2,-20,20); 
TH1D *q_0A=new TH1D("Ex_0A","Ex_0A",_bin*2,-20,20); 
TH1D *q_0B=new TH1D("Ex_0B","Ex_0B",_bin*2,-20,20); 
TH1D *q_1A=new TH1D("Ex_1A","Ex_1A",_bin*2,-20,20); 
TH1D *q_1B=new TH1D("Ex_1B","Ex_1B",_bin*2,-20,20); 
TH1D *q_2A=new TH1D("Ex_2A","Ex_2A",_bin*2,-20,20); 
TH1D *q_2B=new TH1D("Ex_2B","Ex_2B",_bin*2,-20,20); 
TH1D *q_3A=new TH1D("Ex_3A","Ex_3A",_bin*2,-20,20); 
TH1D *q_3B=new TH1D("Ex_3B","Ex_3B",_bin*2,-20,20); 
TH1D *q_4A=new TH1D("Ex_4A","Ex_4A",_bin*2,-20,20); 
TH1D *q_4B=new TH1D("Ex_4B","Ex_4B",_bin*2,-20,20); 
TH1D *q_5A=new TH1D("Ex_5A","Ex_5A",_bin*2,-20,20); 
TH1D *q_5B=new TH1D("Ex_5B","Ex_5B",_bin*2,-20,20); 
TH1D *t_0A=new TH1D("An_0A","An_0A",_bin*2,-20,20); 
TH1D *t_0B=new TH1D("An_0B","An_0B",_bin*2,-20,20); 
TH1D *t_1A=new TH1D("An_1A","An_1A",_bin*2,-20,20); 
TH1D *t_1B=new TH1D("An_1B","An_1B",_bin*2,-20,20); 
TH1D *t_2A=new TH1D("An_2A","An_2A",_bin*2,-20,20); 
TH1D *t_2B=new TH1D("An_2B","An_2B",_bin*2,-20,20); 
TH1D *t_3A=new TH1D("An_3A","An_3A",_bin*2,-20,20); 
TH1D *t_3B=new TH1D("An_3B","An_3B",_bin*2,-20,20); 
TH1D *t_4A=new TH1D("An_4A","An_4A",_bin*2,-20,20); 
TH1D *t_4B=new TH1D("An_4B","An_4B",_bin*2,-20,20); 
TH1D *t_5A=new TH1D("An_5A","An_5A",_bin*2,-20,20); 
TH1D *t_5B=new TH1D("An_5B","An_5B",_bin*2,-20,20); 
Double_t Q_0A[50000];
Double_t Q_0B[50000];
Double_t Q_1A[50000];
Double_t Q_1B[50000];
Double_t Q_2A[50000];
Double_t Q_2B[50000];
Double_t Q_3A[50000];
Double_t Q_3B[50000];
Double_t Q_4A[50000];
Double_t Q_4B[50000];
Double_t Q_5A[50000];
Double_t Q_5B[50000];
for(Int_t i=0;i<50000;i++)Q_0A[i]=-999;
for(Int_t i=0;i<50000;i++)Q_0B[i]=-999;
for(Int_t i=0;i<50000;i++)Q_1A[i]=-999;
for(Int_t i=0;i<50000;i++)Q_1B[i]=-999;
for(Int_t i=0;i<50000;i++)Q_2A[i]=-999;
for(Int_t i=0;i<50000;i++)Q_2B[i]=-999;
for(Int_t i=0;i<50000;i++)Q_3A[i]=-999;
for(Int_t i=0;i<50000;i++)Q_3B[i]=-999;
for(Int_t i=0;i<50000;i++)Q_4A[i]=-999;
for(Int_t i=0;i<50000;i++)Q_4B[i]=-999;
for(Int_t i=0;i<50000;i++)Q_5A[i]=-999;
for(Int_t i=0;i<50000;i++)Q_5B[i]=-999;
Int_t count_all=0;
//ad0
ii0=0;

Double_t q_maxE=40.;
for(Int_t i=0;i<npoints_0A;i++){
    Q_0A[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_0A[i]+eoff[0]-eoffx2[0]*Eb_0A[i]*Eb_0A[i])
    -2.*cos((theta_0A[i]+theoff[0])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_0A[i]+eoff[0]-eoffx2[0]*Eb_0A[i]*Eb_0A[i]))/14.003241988); 
    if(abs(Q_0A[i]-5)<=10&&(Eb_0A[i]+_H2offset)<q_maxE){
    q_0A->Fill(Q_0A[i]);
    q_all->Fill(Q_0A[i]);
    t_0A->Fill(Q_0A[i]);
    }
    //if(abs((theta_0A[i]+theoff[0])-33)<=16&&(Eb_0A[i]+_H2offset)<60)
    if((abs(Eb_0A[i]+eoff[0]-eoffx2[0]*Eb_0A[i]*Eb_0A[i])-100)<99){
    T1E_newtheta_new_bydstar_0A->SetPoint(ii0++,theta_0A[i]+theoff[0],(Eb_0A[i]+eoff[0]-eoffx2[0]*Eb_0A[i]*Eb_0A[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_0A[i]+theoff[0],(Eb_0A[i]+eoff[0]-eoffx2[0]*Eb_0A[i]*Eb_0A[i]));
    }
}
ii0=0;
for(Int_t i=0;i<npoints_0B;i++){
    Q_0B[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_0B[i]+eoff[1]-eoffx2[1]*Eb_0B[i]*Eb_0B[i])
    -2.*cos((theta_0B[i]+theoff[1])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_0B[i]+eoff[1]-eoffx2[1]*Eb_0B[i]*Eb_0B[i]))/14.003241988);
    if(abs(Q_0B[i]-5)<=10&&(Eb_0B[i]+_H2offset)<q_maxE){
    q_0B->Fill(Q_0B[i]);
    q_all->Fill(Q_0B[i]);
    t_0B->Fill(Q_0B[i]);
    }
    //if(abs((theta_0B[i]+theoff[1])-33)<=16&&(Eb_0B[i]+_H2offset)<60)
    if((abs(Eb_0B[i]+eoff[1]-eoffx2[1]*Eb_0B[i]*Eb_0B[i])-100)<99){
    T1E_newtheta_new_bydstar_0B->SetPoint(ii0++,theta_0B[i]+theoff[1],(Eb_0B[i]+eoff[1]-eoffx2[1]*Eb_0B[i]*Eb_0B[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_0B[i]+theoff[1],(Eb_0B[i]+eoff[1]-eoffx2[1]*Eb_0B[i]*Eb_0B[i]));
    }
}
ii0=0;
//ad1
for(Int_t i=0;i<npoints_1A;i++){
    Q_1A[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_1A[i]+eoff[2]-eoffx2[2]*Eb_1A[i]*Eb_1A[i])
    -2.*cos((theta_1A[i]+theoff[2])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_1A[i]+eoff[2]-eoffx2[2]*Eb_1A[i]*Eb_1A[i]))/14.003241988);
    if(abs(Q_1A[i]-5)<=10&&(Eb_1A[i]+_H2offset)<q_maxE){
    q_1A->Fill(Q_1A[i]);
    q_all->Fill(Q_1A[i]);
    t_1A->Fill(Q_1A[i]);
    }
    //if(abs((theta_1A[i]+theoff[2])-33)<=16&&(Eb_1A[i]+_H2offset)<60)
    if((abs(Eb_1A[i]+eoff[2]-eoffx2[2]*Eb_1A[i]*Eb_1A[i])-100)<99){
    T1E_newtheta_new_bydstar_1A->SetPoint(ii0++,theta_1A[i]+theoff[2],(Eb_1A[i]+eoff[2]-eoffx2[2]*Eb_1A[i]*Eb_1A[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_2A[i]+theoff[2],(Eb_1A[i]+eoff[2]-eoffx2[2]*Eb_1A[i]*Eb_1A[i]));
    }
}
ii0=0;
for(Int_t i=0;i<npoints_1B;i++){
    Q_1B[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_1B[i]+eoff[3]-eoffx2[3]*Eb_1B[i]*Eb_1B[i])
    -2.*cos((theta_1B[i]+theoff[3])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_1B[i]+eoff[3]-eoffx2[3]*Eb_1B[i]*Eb_1B[i]))/14.003241988);
    if(abs(Q_1B[i]-5)<=10&&(Eb_1B[i]+_H2offset)<q_maxE){
    q_1B->Fill(Q_1B[i]);
    q_all->Fill(Q_1B[i]);
    t_1B->Fill(Q_1B[i]);
    }
    //if(abs((theta_1B[i]+theoff[3])-33)<=16&&(Eb_1B[i]+_H2offset)<60)
    if((abs(Eb_1B[i]+eoff[3]-eoffx2[3]*Eb_1B[i]*Eb_1B[i])-100)<99){
    T1E_newtheta_new_bydstar_1B->SetPoint(ii0++,theta_1B[i]+theoff[3],(Eb_1B[i]+eoff[3]-eoffx2[3]*Eb_1B[i]*Eb_1B[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_1B[i]+theoff[3],(Eb_1B[i]+eoff[3]-eoffx2[3]*Eb_1B[i]*Eb_1B[i]));
    }
}
ii0=0;
//ad2
for(Int_t i=0;i<npoints_2A;i++){
    Q_2A[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_2A[i]+eoff[4]-eoffx2[4]*Eb_2A[i]*Eb_2A[i])
    -2.*cos((theta_2A[i]+theoff[4])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_2A[i]+eoff[4]-eoffx2[4]*Eb_2A[i]*Eb_2A[i]))/14.003241988);
    if(abs(Q_2A[i]-5)<=10&&(Eb_2A[i]+_H2offset)<q_maxE){
    q_2A->Fill(Q_2A[i]);
    q_all->Fill(Q_2A[i]);
    t_2A->Fill(Q_2A[i]);
    }
    //if(abs((theta_2A[i]+theoff[4])-33)<=16&&(Eb_2A[i]+_H2offset)<60)
    if((abs(Eb_2A[i]+eoff[4]-eoffx2[4]*Eb_2A[i]*Eb_2A[i])-100)<99){
    T1E_newtheta_new_bydstar_2A->SetPoint(ii0++,theta_2A[i]+theoff[4],(Eb_2A[i]+eoff[4]-eoffx2[4]*Eb_2A[i]*Eb_2A[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_2A[i]+theoff[4],(Eb_2A[i]+eoff[4]-eoffx2[4]*Eb_2A[i]*Eb_2A[i]));
    }
}
ii0=0;
for(Int_t i=0;i<npoints_2B;i++){
    Q_2B[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_2B[i]+eoff[5]-eoffx2[5]*Eb_2B[i]*Eb_2B[i])
    -2.*cos((theta_2B[i]+theoff[5])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_2B[i]+eoff[5]-eoffx2[5]*Eb_2B[i]*Eb_2B[i]))/14.003241988);
    if(abs(Q_2B[i]-5)<=10&&(Eb_2B[i]+_H2offset)<q_maxE){
    q_2B->Fill(Q_2B[i]);
    q_all->Fill(Q_2B[i]);
    t_2B->Fill(Q_2B[i]);
    }
    //if(abs((theta_2B[i]+theoff[5])-33)<=16&&(Eb_2B[i]+_H2offset)<60)
    if((abs(Eb_2B[i]+eoff[5]-eoffx2[5]*Eb_2B[i]*Eb_2B[i])-100)<99){
    T1E_newtheta_new_bydstar_2B->SetPoint(ii0++,theta_2B[i]+theoff[5],(Eb_2B[i]+eoff[5]-eoffx2[5]*Eb_2B[i]*Eb_2B[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_2B[i]+theoff[5],(Eb_2B[i]+eoff[5]-eoffx2[5]*Eb_2B[i]*Eb_2B[i]));
    }
}
//ad3
ii0=0;
for(Int_t i=0;i<npoints_3A;i++){
    Q_3A[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_3A[i]+eoff[6]-eoffx2[6]*Eb_3A[i]*Eb_3A[i])
    -2.*cos((theta_3A[i]+theoff[6])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_3A[i]+eoff[6]-eoffx2[6]*Eb_3A[i]*Eb_3A[i]))/14.003241988);
    if(abs(Q_3A[i]-5)<=10&&(Eb_3A[i]+_H2offset)<q_maxE){
    q_3A->Fill(Q_3A[i]);
    q_all->Fill(Q_3A[i]);
    t_3A->Fill(Q_3A[i]);
    }
    //if(abs((theta_3A[i]+theoff[6])-33)<=16&&(Eb_3A[i]+_H2offset)<60)
    if((abs(Eb_3A[i]+eoff[6]-eoffx2[6]*Eb_3A[i]*Eb_3A[i])-100)<99){
    T1E_newtheta_new_bydstar_3A->SetPoint(ii0++,theta_3A[i]+theoff[6],(Eb_3A[i]+eoff[6]-eoffx2[6]*Eb_3A[i]*Eb_3A[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_3A[i]+theoff[6],(Eb_3A[i]+eoff[6]-eoffx2[6]*Eb_3A[i]*Eb_3A[i]));
    }
}
ii0=0;
for(Int_t i=0;i<npoints_3B;i++){
    Q_3B[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_3B[i]+eoff[7]-eoffx2[7]*Eb_3B[i]*Eb_3B[i])
    -2.*cos((theta_3B[i]+theoff[7])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_3B[i]+eoff[7]-eoffx2[7]*Eb_3B[i]*Eb_3B[i]))/14.003241988);
    if(abs(Q_3B[i]-5)<=10&&(Eb_3B[i]+_H2offset)<q_maxE){
    q_3B->Fill(Q_3B[i]);
    q_all->Fill(Q_3B[i]);
    t_3B->Fill(Q_3B[i]);
    }
    //if(abs((theta_3B[i]+theoff[7])-33)<=16&&(Eb_3B[i]+_H2offset)<60)
    if((abs(Eb_3B[i]+eoff[7]-eoffx2[7]*Eb_3B[i]*Eb_3B[i])-100)<99){
    T1E_newtheta_new_bydstar_3B->SetPoint(ii0++,theta_3B[i]+theoff[7],(Eb_3B[i]+eoff[7]-eoffx2[7]*Eb_3B[i]*Eb_3B[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_3B[i]+theoff[7],(Eb_3B[i]+eoff[7]-eoffx2[7]*Eb_3B[i]*Eb_3B[i]));
    }
}
ii0=0;
//ad4
for(Int_t i=0;i<npoints_4A;i++){
    Q_4A[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_4A[i]+eoff[8]-eoffx2[8]*Eb_4A[i]*Eb_4A[i])
    -2.*cos((theta_4A[i]+theoff[8])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_4A[i]+eoff[8]-eoffx2[8]*Eb_4A[i]*Eb_4A[i]))/14.003241988);
    if(abs(Q_4A[i]-5)<=10&&(Eb_4A[i]+_H2offset)<q_maxE){
    q_4A->Fill(Q_4A[i]);
    q_all->Fill(Q_4A[i]);
    t_4A->Fill(Q_4A[i]);
    }
    //if(abs((theta_4A[i]+theoff[8])-33)<=16&&(Eb_4A[i]+_H2offset)<60)
    if((abs(Eb_4A[i]+eoff[8]-eoffx2[8]*Eb_4A[i]*Eb_4A[i])-100)<99){
    T1E_newtheta_new_bydstar_4A->SetPoint(ii0++,theta_4A[i]+theoff[8],(Eb_4A[i]+eoff[8]-eoffx2[8]*Eb_4A[i]*Eb_4A[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_4A[i]+theoff[8],(Eb_4A[i]+eoff[8]-eoffx2[8]*Eb_4A[i]*Eb_4A[i]));
    }
}
ii0=0;
for(Int_t i=0;i<npoints_4B;i++){
    Q_4B[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_4B[i]+eoff[9]-eoffx2[9]*Eb_4B[i]*Eb_4B[i])
    -2.*cos((theta_4B[i]+theoff[9])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_4B[i]+eoff[9]-eoffx2[9]*Eb_4B[i]*Eb_4B[i]))/14.003241988);
    if(abs(Q_4B[i]-5)<=10&&(Eb_4B[i]+_H2offset)<q_maxE){
    //q_4B->Fill(Q_4B[i]);
    //q_all->Fill(Q_4B[i]);
    //t_4B->Fill(Q_4B[i]);
    }
    //if(abs((theta_4B[i]+theoff[9])-33)<=16&&(Eb_4B[i]+_H2offset)<60)
    if((abs(Eb_4B[i]+eoff[9]-eoffx2[9]*Eb_4B[i]*Eb_4B[i])-100)<99){
    //T1E_newtheta_new_bydstar_4B->SetPoint(ii0++,theta_4B[i]+theoff[9],(Eb_4B[i]+eoff[9]-eoffx2[9]*Eb_4B[i]*Eb_4B[i]));
    //T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_4B[i]+theoff[9],(Eb_4B[i]+eoff[9]-eoffx2[9]*Eb_4B[i]*Eb_4B[i]));
    }
}
ii0=0;
//ad5
for(Int_t i=0;i<npoints_5A;i++){
    Q_5A[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_5A[i]+eoff[10]-eoffx2[10]*Eb_5A[i]*Eb_5A[i])
    -2.*cos((theta_5A[i]+theoff[10])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_5A[i]+eoff[10]-eoffx2[10]*Eb_5A[i]*Eb_5A[i]))/14.003241988);
    if(abs(Q_5A[i]-5)<=10&&(Eb_5A[i]+_H2offset)<q_maxE){
    q_5A->Fill(Q_5A[i]);
    q_all->Fill(Q_5A[i]);
    t_5A->Fill(Q_5A[i]);
    }
    //if(abs((theta_5A[i]+theoff[10])-33)<=16&&(Eb_5A[i]+_H2offset)<60)
    if((abs(Eb_5A[i]+eoff[10]-eoffx2[10]*Eb_5A[i]*Eb_5A[i])-100)<99){
    T1E_newtheta_new_bydstar_5A->SetPoint(ii0++,theta_5A[i]+theoff[10],(Eb_5A[i]+eoff[10]-eoffx2[10]*Eb_5A[i]*Eb_5A[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_5A[i]+theoff[10],(Eb_5A[i]+eoff[10]-eoffx2[10]*Eb_5A[i]*Eb_5A[i]));
    }
}
ii0=0;
for(Int_t i=0;i<npoints_5B;i++){
    Q_5B[i]=1.01-((15.0106/14.003241988-1.)*(_15C*15)+(2.01410177811/14.003241988+1.)*(Eb_5B[i]+eoff[11]-eoffx2[11]*Eb_5B[i]*Eb_5B[i])
    -2.*cos((theta_5B[i]+theoff[11])*3.14159/180.)*sqrt(15.0106*2.01410177811*_15C*15*(Eb_5B[i]+eoff[11]-eoffx2[11]*Eb_5B[i]*Eb_5B[i]))/14.003241988);
    if(abs(Q_5B[i]-5)<=10&&(Eb_5B[i]+_H2offset)<q_maxE){
    q_5B->Fill(Q_5B[i]);
    q_all->Fill(Q_5B[i]);
    t_5B->Fill(Q_5B[i]);
    }
    //if(abs((theta_5B[i]+theoff[11])-33)<=16&&(Eb_5B[i]+_H2offset)<60)
    if((abs(Eb_5B[i]+eoff[11]-eoffx2[11]*Eb_5B[i]*Eb_5B[i])-100)<99){
    T1E_newtheta_new_bydstar_5B->SetPoint(ii0++,theta_5B[i]+theoff[11],(Eb_5B[i]+eoff[11]-eoffx2[11]*Eb_5B[i]*Eb_5B[i]));
    T1E_newtheta_new_bydstar_all->SetPoint(count_all++,theta_5B[i]+theoff[11],(Eb_5B[i]+eoff[11]-eoffx2[11]*Eb_5B[i]*Eb_5B[i]));
    }
}

T1E_newtheta_new_bydstar_all->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_all->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_0A->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_0A->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_0B->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_0B->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_1A->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_1A->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_1B->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_1B->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_2A->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_2A->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_2B->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_2B->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_3A->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_3A->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_3B->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_3B->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_4A->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_4A->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_4B->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_4B->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_5A->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_5A->GetYaxis()->SetRangeUser(0 , 100); 
T1E_newtheta_new_bydstar_5B->GetXaxis()->SetLimits(17, 49);
T1E_newtheta_new_bydstar_5B->GetYaxis()->SetRangeUser(0 , 100);

// %%
c1->Clear();
T1E_newtheta_new_bydstar_0A->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_0A->SetMarkerColor(1);
T1E_newtheta_new_bydstar_0A->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_0A = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_0A->GetN()));
   textT1E_newtheta_new_bydstar_0A->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_0A->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_0A->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_0B->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_0B->SetMarkerColor(1);
T1E_newtheta_new_bydstar_0B->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_0B = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_0B->GetN()));
   textT1E_newtheta_new_bydstar_0B->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_0B->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_0B->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_1A->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_1A->SetMarkerColor(1);
T1E_newtheta_new_bydstar_1A->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_1A = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_1A->GetN()));
   textT1E_newtheta_new_bydstar_1A->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_1A->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_1A->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_1B->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_1B->SetMarkerColor(1);
T1E_newtheta_new_bydstar_1B->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_1B = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_1B->GetN()));
   textT1E_newtheta_new_bydstar_1B->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_1B->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_1B->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_2A->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_2A->SetMarkerColor(1);
T1E_newtheta_new_bydstar_2A->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_2A = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_2A->GetN()));
   textT1E_newtheta_new_bydstar_2A->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_2A->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_2A->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_2B->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_2B->SetMarkerColor(1);
T1E_newtheta_new_bydstar_2B->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText *textT1E_newtheta_new_bydstar_2B = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_2B->GetN()));
   textT1E_newtheta_new_bydstar_2B->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_2B->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_2B->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_3A->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_3A->SetMarkerColor(1);
T1E_newtheta_new_bydstar_3A->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_3A = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_3A->GetN()));
   textT1E_newtheta_new_bydstar_3A->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_3A->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_3A->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_3B->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_3B->SetMarkerColor(1);
T1E_newtheta_new_bydstar_3B->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_3B = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_3B->GetN()));
   textT1E_newtheta_new_bydstar_3B->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_3B->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_3B->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_4A->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_4A->SetMarkerColor(1);
T1E_newtheta_new_bydstar_4A->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_4A = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_4A->GetN()));
   textT1E_newtheta_new_bydstar_4A->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_4A->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_4A->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_4B->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_4B->SetMarkerColor(1);
T1E_newtheta_new_bydstar_4B->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_4B = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_4B->GetN()));
   textT1E_newtheta_new_bydstar_4B->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_4B->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_4B->Draw("samep"); // 在图上显示文本
c1->Draw();
// Out:
// Error in <TGraphPainter::PaintGraph>: illegal number of points (0)

// %%
c1->Clear();
T1E_newtheta_new_bydstar_5A->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_5A->SetMarkerColor(1);
T1E_newtheta_new_bydstar_5A->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_5A = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_5A->GetN()));
   textT1E_newtheta_new_bydstar_5A->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_5A->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_5A->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_5B->SetMarkerStyle(3);
T1E_newtheta_new_bydstar_5B->SetMarkerColor(1);
T1E_newtheta_new_bydstar_5B->Draw("ap");
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_5B = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_5B->GetN()));
   textT1E_newtheta_new_bydstar_5B->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_5B->SetTextSize(0.08); // 设置文本大小
   textT1E_newtheta_new_bydstar_5B->Draw("samep"); // 在图上显示文本
c1->Draw();

// %%
c1->Clear();
q_all->Draw();
c1->Draw();

// %%
c1->Clear();
q_0A->Draw();
c1->Draw();

// %%
c1->Clear();
q_0B->Draw();
c1->Draw();

// %%
c1->Clear();
q_1A->Draw();
c1->Draw();

// %%
c1->Clear();
q_1B->Draw();
c1->Draw();

// %%
c1->Clear();
q_2A->Draw();
c1->Draw();

// %%
c1->Clear();
q_2B->Draw();
c1->Draw();

// %%
c1->Clear();
q_3A->Draw();
c1->Draw();

// %%
c1->Clear();
q_3B->Draw();
c1->Draw();

// %%
c1->Clear();
q_4A->Draw();
c1->Draw();

// %%
c1->Clear();
q_4B->Draw();
c1->Draw();

// %%
c1->Clear();
q_5A->Draw();
c1->Draw();

// %%
c1->Clear();
q_5B->Draw();
c1->Draw();

// %%
c1->Clear();
q_all->Fit("g1","","",-2,2);
q_all->Draw();
c1->Draw();
// Out:
//  FCN=4.30449 FROM MIGRAD    STATUS=CONVERGED     122 CALLS         123 TOTAL
//                      EDM=6.04549e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.17715e+01   2.62116e+00   1.47316e-03  -5.32165e-04
//    2  Mean        -1.53924e+00   3.87853e+00   7.78313e-04  -7.81804e-04
//    3  Sigma        3.30826e+00   3.47826e+00   1.84435e-04  -3.85197e-03

// %%
c1->Clear();
q_all->Fit("g1","","",-2,2);
q_all->Draw();
c1->Draw();
// Out:
//  FCN=4.30449 FROM MIGRAD    STATUS=CONVERGED     120 CALLS         121 TOTAL
//                      EDM=6.04309e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.17715e+01   2.62116e+00   1.47316e-03  -5.32046e-04
//    2  Mean        -1.53924e+00   3.87853e+00   7.78313e-04  -7.81649e-04
//    3  Sigma        3.30826e+00   3.47826e+00   1.84435e-04  -3.85125e-03

// %%
c1->Clear();
q_all->Fit("g1","","",4.5,8.5);
q_all->Draw();
c1->Draw();
// Out:
//  FCN=3.65322 FROM MIGRAD    STATUS=CONVERGED      90 CALLS          91 TOTAL
//                      EDM=7.19368e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     8.10113e+00   1.48917e+00   1.19063e-03   7.17990e-04
//    2  Mean         7.07666e+00   6.90925e-01   4.05741e-04  -1.53240e-03
//    3  Sigma        1.74692e+00   7.63728e-01   9.96217e-05   1.15416e-02

// %%
c1->Clear();
q_0A->Fit("g1","","",-2,2);
mean[0]=g1->GetParameter(1);
sigma[0]=g1->GetParameter(2);
q_0A->Draw();
c1->Draw();
// Out:
//  FCN=0.272526 FROM MIGRAD    STATUS=CONVERGED     516 CALLS         517 TOTAL
//                      EDM=3.47972e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.22059e+01   2.36789e+02   3.08377e-03  -2.46649e-04
//    2  Mean        -2.16545e+01   8.77765e+01   1.14263e-03  -6.51337e-04
//    3  Sigma        9.69406e+00   6.36092e+00   2.71280e-03  -2.88629e-04

// %%
c1->Clear();
q_0B->Fit("g1","","",-2,2);
mean[1]=g1->GetParameter(1);
sigma[1]=g1->GetParameter(2);
q_0B->Draw();
c1->Draw();
// Out:
//  FCN=3.76605e-05 FROM MIGRAD    STATUS=CONVERGED     167 CALLS         168 TOTAL
//                      EDM=1.36106e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.00495e+00   5.80323e-01   2.83338e-04  -2.71623e-04
//    2  Mean         1.25000e+00   2.35880e+01   1.20193e-02   0.00000e+00
//    3  Sigma        4.08083e+00   4.08137e+00   9.40299e-02  -3.09635e-06

// %%
c1->Clear();
q_1A->Fit("g1","","",-2,2);
mean[2]=g1->GetParameter(1);
sigma[2]=g1->GetParameter(2);
q_1A->Draw();
c1->Draw();
// Out:
//  FCN=1.81359 FROM MIGRAD    STATUS=CONVERGED     191 CALLS         192 TOTAL
//                      EDM=1.46346e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.33596e+00   8.74127e-01   3.61413e-04  -2.79279e-03
//    2  Mean         1.85336e+00   4.19037e+01   1.70052e-02   7.80059e-05
//    3  Sigma        1.20261e+01   8.81861e+00   1.93649e-02  -9.83835e-06

// %%
c1->Clear();
q_1B->Fit("g1","","",-2,2);
mean[3]=g1->GetParameter(1);
sigma[3]=g1->GetParameter(2);
q_1B->Draw();
c1->Draw();
// Out:
//  FCN=1.14703 FROM MIGRAD    STATUS=CONVERGED      86 CALLS          87 TOTAL
//                      EDM=1.77792e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.97859e+00   1.18151e+00   5.05515e-04   4.70009e-04
//    2  Mean        -4.33842e-01   8.01650e-01   4.78864e-04   7.99959e-04
//    3  Sigma        1.20160e+00   1.24915e+00   1.97207e-04   3.40408e-04

// %%
c1->Clear();
q_2A->Fit("g1","","",-2,2);
mean[4]=g1->GetParameter(1);
sigma[4]=g1->GetParameter(2);
q_2A->Draw();
c1->Draw();
// Out:
//  FCN=0.796751 FROM MIGRAD    STATUS=CONVERGED     286 CALLS         287 TOTAL
//                      EDM=4.58131e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.68970e+00   8.57249e+00   4.12183e-04  -6.05196e-05
//    2  Mean         8.98122e+00   7.03384e+01   3.38069e-03  -4.37381e-06
//    3  Sigma        1.13880e+01   6.27792e+00   7.21916e-03  -4.06754e-05

// %%
c1->Clear();
q_2B->Fit("g1","","",-2,2);
mean[5]=g1->GetParameter(1);
sigma[5]=g1->GetParameter(2);
q_2B->Draw();
c1->Draw();
// Out:
//  FCN=1.58383 FROM MIGRAD    STATUS=CONVERGED     303 CALLS         304 TOTAL
//                      EDM=8.64406e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.34886e+00   2.29584e+00   3.65971e-04  -1.34895e-04
//    2  Mean        -5.73086e+00   4.31831e+01   6.77970e-03  -9.70252e-06
//    3  Sigma        1.20830e+01   6.63457e+00   1.75675e-02** at limit **

// %%
c1->Clear();
q_3A->Fit("g1","","",-2,2);
mean[6]=g1->GetParameter(1);
sigma[6]=g1->GetParameter(2);
q_3A->Draw();
c1->Draw();
// Out:
//  FCN=3.39187e-05 FROM MIGRAD    STATUS=CONVERGED     163 CALLS         164 TOTAL
//                      EDM=4.77662e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   6.1 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.00468e+00   6.07517e-01  -9.36332e-04  -2.36697e-03
//    2  Mean        -5.35314e-01   5.34377e+01   1.72794e-03  -1.10784e-07
//    3  Sigma        1.02621e+01   7.52133e+00   3.90701e-01  -5.43603e-06

// %%
c1->Clear();
q_3B->Fit("g1","","",-2,2);
mean[7]=g1->GetParameter(1);
sigma[7]=g1->GetParameter(2);
q_3B->Draw();
c1->Draw();
// Out:
//  FCN=0.316683 FROM MIGRAD    STATUS=CONVERGED      75 CALLS          76 TOTAL
//                      EDM=1.70956e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     3.74294e+00   2.10692e+00   7.55790e-04  -1.07425e-04
//    2  Mean         1.85196e-01   4.29167e-01   2.05111e-04   2.95518e-04
//    3  Sigma        9.88169e-01   4.60572e-01   5.11688e-05  -1.91549e-03

// %%
c1->Clear();
q_4A->Fit("g1","","",-2,2);
mean[8]=g1->GetParameter(1);
sigma[8]=g1->GetParameter(2);
q_4A->Draw();
c1->Draw();
// Out:
//  FCN=1.29988 FROM MIGRAD    STATUS=CONVERGED      68 CALLS          69 TOTAL
//                      EDM=7.26092e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     2.45784e+00   1.88328e+00   5.59042e-04  -5.12395e-04
//    2  Mean        -2.86481e-01   4.66753e-01   2.64687e-04  -1.93977e-03
//    3  Sigma        9.69096e-01   1.00421e+00   1.02016e-04  -3.23329e-03

// %%
c1->Clear();
q_4B->Fit("g1","","",-2,2);
mean[9]=g1->GetParameter(1);
sigma[9]=g1->GetParameter(2);
q_4B->Draw();
c1->Draw();
// Out:
// Warning in <Fit>: Fit data is empty

// %%
c1->Clear();
q_5A->Fit("g1","","",-2,2);
mean[10]=g1->GetParameter(1);
sigma[10]=g1->GetParameter(2);
q_5A->Draw();
c1->Draw();
// Out:
//  FCN=1.43329 FROM MIGRAD    STATUS=CONVERGED     326 CALLS         327 TOTAL
//                      EDM=1.35396e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.75230e+00   5.12846e+00   5.20627e-04  -1.30060e-03
//    2  Mean        -6.76025e+00   3.14050e+01   3.18051e-03  -2.37109e-04
//    3  Sigma        8.07564e+00   7.14239e+00   1.43659e-02  -5.46836e-05

// %%
c1->Clear();
q_5B->Fit("g1","","",-2,2);
mean[11]=g1->GetParameter(1);
sigma[11]=g1->GetParameter(2);
q_5B->Draw();
c1->Draw();
// Out:
//  FCN=0.746403 FROM MIGRAD    STATUS=CALL LIMIT   1351 CALLS        1352 TOTAL
//                      EDM=2.40035e-05    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  24.9 per cent
//   EXT PARAMETER                APPROXIMATE        STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     7.67557e+03   5.15746e+04  -7.76275e-02  -2.00567e-06
//    2  Mean        -5.32951e+01   6.15180e+01  -1.86631e-01  -4.49535e-03
//    3  Sigma        1.29201e+01   1.33713e+01   1.14471e-02  -7.33815e-02
// Warning in <Fit>: Abnormal termination of minimization.

// %%
TGraph *tafmean=new TGraph();
//tafmean->GetXaxis()->SetLimits(17, 49);
//tafmean->GetYaxis()->SetRangeUser(0 , 60); 
for(Int_t ii=0;ii<12;ii++){
    cout<<mean[ii]<<'\t';
}
cout<<'\n';
for(Int_t ii=0;ii<12;ii++){
    cout<<sigma[ii]<<'\t';
}
// Out:
// -21.6545	1.25	1.85336	-0.433842	8.98122	-5.73086	-0.535314	0.185196	-0.286481	-0.286481	-6.76025	-53.2951
// 9.69406	4.08083	12.0261	1.2016	11.388	12.083	10.2621	0.988169	0.969096	0.969096	8.07564	12.9201

// %%
c1->Clear();
t_0A->Fit("g1","","",4,10);
mean2[0]=g1->GetParameter(1);
sigma2[0]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_0A->Draw();
c1->Draw();
// Out:
//  FCN=0.398723 FROM MIGRAD    STATUS=CONVERGED     284 CALLS         285 TOTAL
//                      EDM=8.06584e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.73510e+00   6.75643e+00   3.89275e-04  -5.16458e-04
//    2  Mean         2.26611e+01   7.07431e+01   3.87120e-03   8.49119e-05
//    3  Sigma        1.63252e+01   1.60266e+01   5.46629e-03  -2.20273e-04
// 22.6611

// %%
c1->Clear();
t_0B->Fit("g1","","",4,10);
mean2[1]=g1->GetParameter(1);
sigma2[1]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_0B->Draw();
c1->Draw();
// Out:
//  FCN=6.55754e-11 FROM HESSE     STATUS=NOT POSDEF     16 CALLS          77 TOTAL
//                      EDM=1.30866e-10    STRATEGY= 1      ERR MATRIX NOT POS-DEF
//   EXT PARAMETER                APPROXIMATE        STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     2.48446e+00   1.82022e+01   1.40126e-04   5.79241e-06
//    2  Mean         8.76586e+00   8.52921e+00   8.90494e-05   1.51500e-05
//    3  Sigma        1.49421e+00   1.18494e+01   3.49432e-06  -8.27171e-06
// 8.76586

// %%
c1->Clear();
t_1A->Fit("g1","","",4,10);
mean2[2]=g1->GetParameter(1);
sigma2[2]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_1A->Draw();
c1->Draw();
// Out:
//  FCN=0.543134 FROM MIGRAD    STATUS=CALL LIMIT   1352 CALLS        1353 TOTAL
//                      EDM=0.000144176    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  37.0 per cent
//   EXT PARAMETER                APPROXIMATE        STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     2.01487e+04   1.39087e+05   7.41844e+02  -1.96766e-06
//    2  Mean         6.18664e+01   5.43345e+01   2.15380e-01   1.31299e-02
//    3  Sigma        1.26076e+01   1.33383e+01   4.45180e-03  -3.08090e-01
// 61.8664
// Warning in <Fit>: Abnormal termination of minimization.

// %%
c1->Clear();
t_1B->Fit("g1","","",4,10);
mean2[3]=g1->GetParameter(1);
sigma2[3]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_1B->Draw();
c1->Draw();
// Out:
//  FCN=0.379144 FROM MIGRAD    STATUS=CONVERGED     105 CALLS         106 TOTAL
//                      EDM=6.27989e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.25281e+00   7.52868e-01   2.78811e-04   1.51555e-03
//    2  Mean         7.12216e+00   1.35397e+00   7.64294e-04   2.19361e-04
//    3  Sigma        1.66888e+00   2.71791e+00   3.68701e-04   1.57405e-03
// 7.12216

// %%
c1->Clear();
t_2A->Fit("g1","","",4,10);
mean2[4]=g1->GetParameter(1);
sigma2[4]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_2A->Draw();
c1->Draw();
// Out:
//  FCN=1.22194 FROM MIGRAD    STATUS=CONVERGED     114 CALLS         115 TOTAL
//                      EDM=1.69779e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.43526e+00   5.25586e-01   3.18124e-04   1.29421e-03
//    2  Mean         7.77368e+00   5.47148e+00   2.85332e-03  -1.61765e-04
//    3  Sigma        4.41749e+00   9.19490e+00   6.80923e-04   1.75894e-03
// 7.77368

// %%
c1->Clear();
t_2B->Fit("g1","","",4,10);
mean2[5]=g1->GetParameter(1);
sigma2[5]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_2B->Draw();
c1->Draw();
// Out:
//  FCN=0.352969 FROM MIGRAD    STATUS=CONVERGED     378 CALLS         379 TOTAL
//                      EDM=1.10859e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     3.17742e+00   2.00283e+01   6.97520e-04  -6.21451e-04
//    2  Mean         3.37160e+01   7.86503e+01   2.75198e-03   1.67513e-04
//    3  Sigma        1.80131e+01   1.56690e+01   6.02237e-03  -8.77461e-05
// 33.716

// %%
c1->Clear();
t_3A->Fit("g1","","",4,10);
mean2[6]=g1->GetParameter(1);
sigma2[6]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_3A->Draw();
c1->Draw();
// Out:
//  FCN=0.0263633 FROM MIGRAD    STATUS=CONVERGED     110 CALLS         111 TOTAL
//                      EDM=1.6195e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     2.30703e+00   1.63549e+00   4.66978e-04   4.40920e-05
//    2  Mean         7.46755e+00   9.41249e-01   4.07777e-04  -1.29180e-04
//    3  Sigma        1.75861e+00   1.13045e+00   7.63594e-05   6.78168e-04
// 7.46755

// %%
c1->Clear();
t_3B->Fit("g1","","",4,10);
mean2[7]=g1->GetParameter(1);
sigma2[7]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_3B->Draw();
c1->Draw();
// Out:
//  FCN=1.19791 FROM MIGRAD    STATUS=CONVERGED     118 CALLS         119 TOTAL
//                      EDM=8.87338e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.20937e+00   5.86245e-01   2.79349e-04   2.20756e-03
//    2  Mean         7.68393e+00   3.18119e+00   1.93137e-03  -3.66973e-04
//    3  Sigma        3.68622e+00   8.99224e+00   5.19751e-04   1.81657e-03
// 7.68393

// %%
c1->Clear();
t_4A->Fit("g1","","",4,10);
mean2[8]=g1->GetParameter(1);
sigma2[8]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_4A->Draw();
c1->Draw();
// Out:
//  FCN=1.11018 FROM MIGRAD    STATUS=CONVERGED     217 CALLS         218 TOTAL
//                      EDM=5.98319e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   5.2 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.61602e+00   3.99547e+00   2.48160e-03  -5.70301e-04
//    2  Mean         2.03284e+01   5.97287e+01   2.55180e-02   4.76652e-05
//    3  Sigma        1.75094e+01   9.12789e+00   1.65656e-03   1.04986e-04
// 20.3284

// %%
c1->Clear();
t_4B->Fit("g1","","",4,10);
mean2[9]=g1->GetParameter(1);
sigma2[9]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_4B->Draw();
c1->Draw();
// Out:
// 20.3284
// Warning in <Fit>: Fit data is empty

// %%
c1->Clear();
t_5A->Fit("g1","","",4,10);
mean2[10]=g1->GetParameter(1);
sigma2[10]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_5A->Draw();
c1->Draw();
// Out:
//  FCN=0.244122 FROM MIGRAD    STATUS=CONVERGED      79 CALLS          80 TOTAL
//                      EDM=1.68943e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.54704e+00   1.15759e+00   3.86763e-04   3.47754e-05
//    2  Mean         6.24591e+00   1.20776e+00   6.38529e-04   1.32654e-03
//    3  Sigma        1.76286e+00   2.07789e+00   1.74270e-04  -1.69791e-03
// 6.24591

// %%
c1->Clear();
t_5B->Fit("g1","","",4,10);
mean2[11]=g1->GetParameter(1);
sigma2[11]=g1->GetParameter(2);
cout<<g1->GetParameter(1)<<'\n';
t_5B->Draw();
c1->Draw();
// Out:
//  FCN=4.032e-05 FROM MIGRAD    STATUS=CONVERGED     151 CALLS         152 TOTAL
//                      EDM=8.25666e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.00574e+00   5.58859e-01   2.45816e-04  -2.07135e-03
//    2  Mean         7.46183e+00   9.35163e+01   4.02316e-02   8.91884e-06
//    3  Sigma        1.88147e+01   1.85161e+01   8.03786e-02   5.79849e-06
// 7.46183

// %%
TGraph *themean=new TGraph();
TGraph *thesigma=new TGraph();
Double_t nowmean,nowsigma;
for(Int_t ii=0;ii<12;ii++){
    cout<<mean[ii]<<'\t';
    themean->SetPoint(ii,ii,mean[ii]);
}
cout<<'\n';
for(Int_t ii=0;ii<12;ii++){
    cout<<sigma[ii]<<'\t';
    thesigma->SetPoint(ii,ii,sigma[ii]);
}
// Out:
// -21.6545	1.25	1.85336	-0.433842	8.98122	-5.73086	-0.535314	0.185196	-0.286481	-0.286481	-6.76025	-53.2951
// 9.69406	4.08083	12.0261	1.2016	11.388	12.083	10.2621	0.988169	0.969096	0.969096	8.07564	12.9201

// %%
TGraph *themean2=new TGraph();
TGraph *thesigma2=new TGraph();
Double_t nowmean2,nowsigma2;
for(Int_t ii=0;ii<12;ii++){
    cout<<mean2[ii]<<'\t';
    themean2->SetPoint(ii,ii,mean2[ii]);
}
cout<<'\n';
for(Int_t ii=0;ii<12;ii++){
    cout<<sigma2[ii]<<'\t';
    thesigma2->SetPoint(ii,ii,sigma2[ii]);
}
// Out:
// 22.6611	8.76586	61.8664	7.12216	7.77368	33.716	7.46755	7.68393	20.3284	20.3284	6.24591	7.46183
// 16.3252	1.49421	12.6076	1.66888	4.41749	18.0131	1.75861	3.68622	17.5094	17.5094	1.76286	18.8147

// %%
c1->Clear();
themean->SetMarkerStyle(3);
themean->Draw();
c1->Draw();

// %%
c1->Clear();
thesigma->SetMarkerStyle(23);
thesigma->Draw();
c1->Draw();

// %%
c1->Clear();
themean2->SetMarkerStyle(3);
themean2->Draw();
c1->Draw();

// %%
c1->Clear();
thesigma2->SetMarkerStyle(23);
thesigma2->Draw();
c1->Draw();

// %%
c1->Clear();
T1E_newtheta_new_bydstar_all->SetMarkerStyle(6);
T1E_newtheta_new_bydstar_all->SetMarkerColor(1);
T1E_newtheta_new_bydstar_all->Draw("ap");
T1Etheta_B14He3_0->SetMarkerStyle(6);
T1Etheta_B14He3_6100->SetMarkerStyle(6);
T1Etheta_B14He3_0->SetMarkerColor(2);
T1Etheta_B14He3_6100->SetMarkerColor(2);
T1Etheta_B14He3_0->Draw("samep");
T1Etheta_B14He3_6100->Draw("samep");
   TText* textT1E_newtheta_new_bydstar_all = new TText(43, 90, Form("%d", T1E_newtheta_new_bydstar_all->GetN()));
   textT1E_newtheta_new_bydstar_all->SetTextAlign(15); // 设置文本对齐方式
   textT1E_newtheta_new_bydstar_all->SetTextSize(0.08); // 设置文本大小
   //textT1E_newtheta_new_bydstar_all->Draw("samep"); // 在图上显示文本
c1->Draw();
