// %%
//%jsroot on
#include "TROOT.h"
#include "TFile.h"
#include "TCanvas.h"
#include "TGraph.h"

// %%
TCanvas *c1=new TCanvas("c1","c1");
TCanvas *c2=new TCanvas("c2","c2");
TCanvas *c3=new TCanvas("c3","c3",550,600);
TCanvas *c4=new TCanvas("c4","c4",400,600);

// %%
double aa,bb;
  int count_15Cd3He_et_l=0,count_15Cd3He_et_h=0;
  int count_15Cdd_et_l=0,count_15Cdd_et_h=0;
  int count_15Cdt_et_l=0,count_15Cdt_et_h=0;
  int count_15Cd4He_et_l=0,count_15Cd4He_et_h=0;
  int count_15Cpd_et_l=0,count_15Cpd_et_h=0;
  int count_15Cpt_et_l=0,count_15Cpt_et_h=0;
  int count_15Cp3He_et_l=0,count_15Cp3He_et_h=0;
  TGraph *lise15Cd3He_et_l=new TGraph();TGraph *lise15Cd3He_et_h=new TGraph();
  TGraph *lise15Cdd_et_l=new TGraph();TGraph *lise15Cdd_et_h=new TGraph();
  TGraph *lise15Cdt_et_l=new TGraph();TGraph *lise15Cdt_et_h=new TGraph();
  TGraph *lise15Cd4He_et_l=new TGraph();TGraph *lise15Cd4He_et_h=new TGraph();
  TGraph *lise15Cpd_et_l=new TGraph();TGraph *lise15Cpd_et_h=new TGraph();
  TGraph *lise15Cpt_et_l=new TGraph();TGraph *lise15Cpt_et_h=new TGraph();
  TGraph *lise15Cp3He_et_l=new TGraph();TGraph *lise15Cp3He_et_h=new TGraph();

Int_t mykey=0;
/*
  ifstream in1("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cdd_et2.txt");
  string ssa;
  Double_t El,thetal,Eh,thetah;
  if(in1.is_open()){
    getline(in1,ssa);
    while(!in1.eof())
    {
      mykey++;
      in1>>thetah>>Eh>>thetal>>El;
      if(mykey%10==0)lise15Cdd_et_l->SetPoint(count_15Cdd_et_l++,thetal,El*2);
      if(mykey%10==0)lise15Cdd_et_h->SetPoint(count_15Cdd_et_h++,thetah,Eh*13);
    }
  }
  in1.close();
*/

ifstream in1("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cdd_et2.txt");
string ssa;
Double_t El, thetal, Eh, thetah;
if(in1.is_open()) {
    getline(in1, ssa);
    double last_theta_l = -1000.0;  // 低角度最后记录点
    double last_theta_h = -1000.0;  // 高角度最后记录点
    const double min_delta = 5.;   // 最小角度间隔（度）- 根据数据密度调整
    
    while(in1 >> thetah >> Eh >> thetal >> El) {
        // 动态稀释低角度数据
        if (fabs(thetal - last_theta_l) >= min_delta) {
            lise15Cdd_et_l->SetPoint(count_15Cdd_et_l++, thetal, El*2);
            last_theta_l = thetal;
        }
        
        // 动态稀释高角度数据
        if (fabs(thetah - last_theta_h) >= min_delta) {
            lise15Cdd_et_h->SetPoint(count_15Cdd_et_h++, thetah, Eh*13);
            last_theta_h = thetah;
        }
    }
}
in1.close();

  ifstream in2("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cd3He_et3.txt");
  if(in2.is_open()){
    getline(in2,ssa);
    while(!in2.eof())
    {
      in2>>thetah>>Eh>>thetal>>El;
      lise15Cd3He_et_l->SetPoint(count_15Cd3He_et_l++,thetal,El*3);
      lise15Cd3He_et_h->SetPoint(count_15Cd3He_et_h++,thetah,Eh*13);
    }
  }
  in2.close();

  ifstream in3("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cdt_et.txt");
  if(in3.is_open()){
    getline(in3,ssa);
    while(!in3.eof())
    {
      mykey++;
      in3>>thetah>>Eh>>thetal>>El;
      if(mykey%10==0)lise15Cdt_et_l->SetPoint(count_15Cdt_et_l++,thetal,El*3);
      if(mykey%10==0)lise15Cdt_et_h->SetPoint(count_15Cdt_et_h++,thetah,Eh*13);
    }
  }
  in3.close();

  ifstream in4("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cd4He_et.txt");
  if(in4.is_open()){
    getline(in4,ssa);
    while(!in4.eof())
    {
      mykey++;
      in4>>thetah>>Eh>>thetal>>El;
      if(mykey%10==0)lise15Cd4He_et_l->SetPoint(count_15Cd4He_et_l++,thetal,El*4);
      if(mykey%10==0)lise15Cd4He_et_h->SetPoint(count_15Cd4He_et_h++,thetah,Eh*13);
    }
  }
  in4.close();

  ifstream in5("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cpd_et.txt");
  if(in5.is_open()){
    getline(in5,ssa);
    while(!in5.eof())
    {
      mykey++;
      in5>>thetah>>Eh>>thetal>>El;
      if(mykey%10==0)lise15Cpd_et_l->SetPoint(count_15Cpd_et_l++,thetal,El*2);
      if(mykey%10==0)lise15Cpd_et_h->SetPoint(count_15Cpd_et_h++,thetah,Eh*13);
    }
  }
  in5.close();

  ifstream in6("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cpt_et.txt");
  if(in6.is_open()){
    getline(in6,ssa);
    while(!in6.eof())
    {
      mykey++;
      in6>>thetah>>Eh>>thetal>>El;
      if(mykey%10==0)lise15Cpt_et_l->SetPoint(count_15Cpt_et_l++,thetal,El*3);
      if(mykey%10==0)lise15Cpt_et_h->SetPoint(count_15Cpt_et_h++,thetah,Eh*13);
    }
  }
  in6.close();


  ifstream in7("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cp3He_et.txt");
  if(in7.is_open()){
    getline(in7,ssa);
    while(!in7.eof())
    {
      mykey++;
      in7>>thetah>>Eh>>thetal>>El;
      if(mykey%10==1)lise15Cp3He_et_l->SetPoint(count_15Cp3He_et_l++,thetal,El*3);
      if(mykey%10==1)lise15Cp3He_et_h->SetPoint(count_15Cp3He_et_h++,thetah,Eh*13);
    }
  }
  in7.close();

/*
ifstream in7("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cp3He_et.txt");
if(in7.is_open()) {
    getline(in7, ssa);
    double last_theta = -1000.0; // 初始值
    const double min_delta = 1.;// 最小角度间隔（度），根据需求调整
    
    while(in7 >> thetah >> Eh >> thetal >> El) {
        // 动态稀释低角度数据
        if (fabs(thetal - last_theta) >= min_delta) {
            lise15Cp3He_et_l->SetPoint(count_15Cp3He_et_l++, thetal, El*3);
            last_theta = thetal; // 更新最后记录的角度
        }
        
        // 高角度仍按原逻辑（可选稀释）
        if (mykey++ % 10 == 0) {
            lise15Cp3He_et_h->SetPoint(count_15Cp3He_et_h++, thetah, Eh*13);
        }
    }
}
in7.close();
*/

// %%
  int count_15Cd3He_tt_l=0,count_15Cd3He_tt_h=0;
  int count_15Cdd_tt_l=0,count_15Cdd_tt_h=0;
  int count_15Cdt_tt_l=0,count_15Cdt_tt_h=0;
  int count_15Cd4He_tt_l=0,count_15Cd4He_tt_h=0;
  int count_15Cpd_tt_l=0,count_15Cpd_tt_h=0;
  int count_15Cpt_tt_l=0,count_15Cpt_tt_h=0;
  TGraph *lise15Cd3He_tt_l=new TGraph();TGraph *lise15Cd3He_tt_h=new TGraph();
  TGraph *lise15Cdd_tt_l=new TGraph();TGraph *lise15Cdd_tt_h=new TGraph();
  TGraph *lise15Cdt_tt_l=new TGraph();TGraph *lise15Cdt_tt_h=new TGraph();
  TGraph *lise15Cd4He_tt_l=new TGraph();TGraph *lise15Cd4He_tt_h=new TGraph();
  TGraph *lise15Cpd_tt_l=new TGraph();TGraph *lise15Cpd_tt_h=new TGraph();
  TGraph *lise15Cpt_tt_l=new TGraph();TGraph *lise15Cpt_tt_h=new TGraph();

  ifstream in21("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cdd_tt2.txt");
  if(in21.is_open()){
    getline(in21,ssa);
    while(!in21.eof())
    {
      in21>>thetah>>thetal;
      lise15Cdd_tt_l->SetPoint(count_15Cdd_tt_l++,thetah,thetal);
    }
  }
  in21.close();

  ifstream in22("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cd3He_tt2.txt");
  if(in22.is_open()){
    getline(in22,ssa);
    while(!in22.eof())
    {
      in22>>thetah>>thetal;
      lise15Cd3He_tt_l->SetPoint(count_15Cd3He_tt_l++,thetah,thetal);
    }
  }
  in22.close();

  ifstream in23("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cdt_tt.txt");
  if(in23.is_open()){
    getline(in23,ssa);
    while(!in23.eof())
    {
      in23>>thetah>>thetal;
      lise15Cdt_tt_l->SetPoint(count_15Cdt_tt_l++,thetah,thetal);
    }
  }
  in23.close();

  ifstream in24("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cd4He_tt.txt");
  if(in24.is_open()){
    getline(in24,ssa);
    while(!in24.eof())
    {
      in24>>thetah>>thetal;
      lise15Cd4He_tt_l->SetPoint(count_15Cd4He_tt_l++,thetah,thetal);
    }
  }
  in24.close();

  ifstream in25("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cpd_tt.txt");
  if(in25.is_open()){
    getline(in25,ssa);
    while(!in25.eof())
    {
      in25>>thetah>>thetal;
      lise15Cpd_tt_l->SetPoint(count_15Cpd_tt_l++,thetah,thetal);
    }
  }
  in25.close();

  ifstream in26("/home/zhuhy/JNBook/Experiment2022/taf/check/angle/txt/15C_d3He/15Cpt_tt.txt");
  if(in26.is_open()){
    getline(in26,ssa);
    while(!in26.eof())
    {
      in26>>thetah>>thetal;
      lise15Cpt_tt_l->SetPoint(count_15Cpt_tt_l++,thetah,thetal);
    }
  }
  in26.close();

// %%
c1->Clear();
lise15Cd3He_et_l->GetXaxis()->SetLimits(0, 60);
lise15Cd3He_et_l->GetYaxis()->SetRangeUser(0 , 100); 
lise15Cd3He_et_l->SetMarkerStyle(6);
lise15Cdd_et_l->SetMarkerStyle(6);
lise15Cdt_et_l->SetMarkerStyle(6);
lise15Cd4He_et_l->SetMarkerStyle(6);
lise15Cpd_et_l->SetMarkerStyle(6);
lise15Cpt_et_l->SetMarkerStyle(6);
lise15Cd3He_et_l->SetMarkerColor(2);
lise15Cdd_et_l->SetMarkerColor(1);
lise15Cdt_et_l->SetMarkerColor(4);
lise15Cd4He_et_l->SetMarkerColor(6);
lise15Cpd_et_l->SetMarkerColor(8);
lise15Cpt_et_l->SetMarkerColor(16);
lise15Cd3He_et_l->Draw("ap");
lise15Cdd_et_l->Draw("samep");
lise15Cdt_et_l->Draw("samep");
lise15Cd4He_et_l->Draw("samep");
lise15Cpd_et_l->Draw("samep");
lise15Cpt_et_l->Draw("samep");
c1->Draw();

// %%
c1->Clear();
lise15Cd3He_et_l->GetXaxis()->SetLimits(0, 60);
lise15Cd3He_et_l->GetYaxis()->SetRangeUser(0 , 50); 
lise15Cd3He_et_l->SetMarkerStyle(0);
lise15Cdd_et_l->SetMarkerStyle(0);
lise15Cdt_et_l->SetMarkerStyle(0);
lise15Cd4He_et_l->SetMarkerStyle(0);
lise15Cpd_et_l->SetMarkerStyle(0);
lise15Cpt_et_l->SetMarkerStyle(0);
lise15Cp3He_et_l->SetMarkerStyle(0);
lise15Cd3He_et_l->SetLineStyle(1);
lise15Cdd_et_l->SetLineStyle(9);
lise15Cdt_et_l->SetLineStyle(2);
lise15Cd4He_et_l->SetLineStyle(2);
lise15Cpd_et_l->SetLineStyle(2);
lise15Cpt_et_l->SetLineStyle(2);
lise15Cp3He_et_l->SetLineStyle(3);
lise15Cd3He_et_l->SetLineWidth(3);
lise15Cdd_et_l->SetLineWidth(2);
lise15Cdt_et_l->SetLineWidth(2);
lise15Cd4He_et_l->SetLineWidth(2);
lise15Cpd_et_l->SetLineWidth(2);
lise15Cpt_et_l->SetLineWidth(2);
lise15Cp3He_et_l->SetLineWidth(2);
lise15Cd3He_et_l->SetLineColor(2);
lise15Cdd_et_l->SetLineColor(1);
lise15Cdt_et_l->SetLineColor(4);
lise15Cd4He_et_l->SetLineColor(6);
lise15Cpd_et_l->SetLineColor(8);
lise15Cpt_et_l->SetLineColor(16);
lise15Cp3He_et_l->SetLineColor(4);
lise15Cd3He_et_l->Draw("AC");
lise15Cdd_et_l->Draw("C same");
//lise15Cdt_et_l->Draw("C same");
lise15Cd4He_et_l->Draw("C same");
//lise15Cpd_et_l->Draw("C same");
//lise15Cpt_et_l->Draw("C same");
lise15Cp3He_et_l->Draw("C same");
c1->Draw();

// %%
c1->Clear();
lise15Cd3He_et_h->GetXaxis()->SetLimits(0, 16);
lise15Cd3He_et_h->GetYaxis()->SetRangeUser(250 , 450); 
lise15Cd3He_et_h->SetMarkerStyle(0);
lise15Cdd_et_h->SetMarkerStyle(0);
lise15Cdt_et_h->SetMarkerStyle(0);
lise15Cd4He_et_h->SetMarkerStyle(0);
lise15Cpd_et_h->SetMarkerStyle(0);
lise15Cpt_et_h->SetMarkerStyle(0);
lise15Cd3He_et_h->SetLineStyle(1);
lise15Cdd_et_h->SetLineStyle(2);
lise15Cdt_et_h->SetLineStyle(2);
lise15Cd4He_et_h->SetLineStyle(2);
lise15Cpd_et_h->SetLineStyle(2);
lise15Cpt_et_h->SetLineStyle(2);
lise15Cd3He_et_h->SetLineWidth(3);
lise15Cdd_et_h->SetLineWidth(2);
lise15Cdt_et_h->SetLineWidth(2);
lise15Cd4He_et_h->SetLineWidth(2);
lise15Cpd_et_h->SetLineWidth(2);
lise15Cpt_et_h->SetLineWidth(2);
lise15Cd3He_et_h->SetLineColor(2);
lise15Cdd_et_h->SetLineColor(1);
lise15Cdt_et_h->SetLineColor(4);
lise15Cd4He_et_h->SetLineColor(6);
lise15Cpd_et_h->SetLineColor(8);
lise15Cpt_et_h->SetLineColor(16);
lise15Cd3He_et_h->Draw("AC");
//lise15Cdd_et_h->Draw("C same");
//lise15Cdt_et_h->Draw("C same");
lise15Cd4He_et_h->Draw("C same");
//lise15Cpd_et_h->Draw("C same");
//lise15Cpt_et_h->Draw("C same");
c1->Draw();

// %%
c4->Clear();
lise15Cd3He_tt_l->GetXaxis()->SetLimits(0, 16);
lise15Cd3He_tt_l->GetYaxis()->SetRangeUser(0 , 60); 
lise15Cd3He_tt_l->SetMarkerStyle(6);
lise15Cdd_tt_l->SetMarkerStyle(6);
lise15Cdt_tt_l->SetMarkerStyle(6);
lise15Cd4He_tt_l->SetMarkerStyle(6);
lise15Cpd_tt_l->SetMarkerStyle(6);
lise15Cpt_tt_l->SetMarkerStyle(6);
lise15Cd3He_tt_l->SetMarkerColor(2);
lise15Cdd_tt_l->SetMarkerColor(1);
lise15Cdt_tt_l->SetMarkerColor(4);
lise15Cd4He_tt_l->SetMarkerColor(6);
lise15Cpd_tt_l->SetMarkerColor(8);
lise15Cpt_tt_l->SetMarkerColor(16);
lise15Cd3He_tt_l->Draw("ap");
lise15Cdd_tt_l->Draw("samep");
lise15Cdt_tt_l->Draw("samep");
lise15Cd4He_tt_l->Draw("samep");
lise15Cpd_tt_l->Draw("samep");
lise15Cpt_tt_l->Draw("samep");
c4->Draw();
